# %%
# importing the required module 
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
  
# read csv file
walking = pd.read_csv('../lab8-dataset/WALKING.csv')
walking
# Out:
#                timestamp   accel_x    accel_y   accel_z    gyro_x    gyro_y  \
# 8053921773725  -0.883179  1.508240   9.011398 -0.402206  0.077042 -0.192047
# 8053926809125  -0.859634  1.496918   9.453842  0.000000  0.000000  0.000000
# 8053931844525  -0.838913  1.510834   9.847977 -0.391907 -0.110809 -0.127625
# 8053936879926  -0.772034  1.532089  10.237396 -0.349976 -0.206604 -0.099014
# 8053941915326  -0.683975  1.533402  10.469177 -0.285629 -0.302750 -0.073761
# ...                  ...       ...        ...       ...       ...       ...
# 8076092618803  -0.668900  1.024261  10.868851 -0.003342  0.089264 -0.067215
# 8076097654203  -0.771667  0.975876  10.488922  0.029312  0.091171 -0.065018
# 8076102689603  -0.599350  0.979950  10.136169  0.051102  0.099884 -0.061279
# 8076107725004  -0.295120  0.931442   9.666077  0.056076  0.111725 -0.053421
# 8076112760404  -1.118729  1.055160   9.044693  0.044022  0.128464 -0.048889
#
#                   gyro_z      mag_x      mag_y  mag_z
# 8053921773725   0.000000   0.000000   0.000000    NaN
# 8053926809125   0.000000   0.000000   0.000000    NaN
# 8053931844525   0.000000   0.000000   0.000000    NaN
# 8053936879926   0.000000   0.000000   0.000000    NaN
# 8053941915326   0.000000   0.000000   0.000000    NaN
# ...                  ...        ...        ...    ...
# 8076092618803  17.338562 -18.896484 -47.998047    NaN
# 8076097654203  17.338562 -18.896484 -47.998047    NaN
# 8076102689603  17.338562 -18.896484 -47.998047    NaN
# 8076107725004  17.512512 -18.435669 -47.749330    NaN
# 8076112760404  17.512512 -18.435669 -47.749330    NaN
#
# [4408 rows x 10 columns]
